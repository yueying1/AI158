# %% [markdown]
# 斐波那契数列的是这样一个数列：1、1、2、3、5、8、13、21、34....，即第一项 f(1) = 1,第二项 f(2) = 1.....,第 n 项目为 f(n) = f(n-1) + f(n-2)。求第 n 项的值是多少。

# %%
def fibonacciSequence(n):
    if n == 1 or n == 2 :
        return 1
    return fibonacciSequence(n -1) + fibonacciSequence(n - 2)


n = int(input('请输入斐波那契数列的n：'))
print(fibonacciSequence(n))
# Out:
# 34

# %% [markdown]
# 一只青蛙一次可以跳上1级台阶，也可以跳上2级。求该青蛙跳上一个n级的台阶总共有多少种跳法。

# %%
def f(n):
    if n <= 2 :
        return n
    return f(n - 1) + f(n - 2)
n = int(input('请输入台阶的数量：'))
print(f(n))

# %% [markdown]
# 反向输出字符串反转单链表。例如链表为：1->2->3->4。反转后为 4->3->2->1

# %%
def f(s):
    if len(s) == 0 :
        return s
    return s[len(s) -1] + f(s[:len(s) -1])

f('123456')
# Out:
# '654321'

# %% [markdown]
# 计算一个整数的各位数字之和

# %%
def f(n):
    if n == 0 :
        return 0
    return n % 10 + f(n // 10)

print(f(123456))
# Out:
# 21

# %% [markdown]
# 回文字符串的判断

# %%
def f(s):
    if len(s) <= 1  :
        return True
    elif s[0] == s[-1] :
        return f(s[1:-1])
    else:
        return False

print(f('1234321'))
print(f('123456'))
# Out:
# True
# False

# %% [markdown]
# 古代有一个梵塔，塔内有三个座A、B、C，A座上有64个盘子，盘子大小不等，大的在下，小的在上。有一个和尚想把这64个盘子从A座移到C座，但每次只能允许移动一个盘子，并且在移动过程中，3个座上的盘子始终保持大盘在下，小盘在上。在移动过程中可以利用B座。要求输入层数，运算后输出每步是如何移动的。

# %%
def move(n,a,b,c):
    # n: 层数  a: A   b: A   c: C
    if n == 1 :
        print(f'移动盘子1：{a} -> {c}')
        return
    move(n -1, a, c, b)
    print(f'移动盘子{n}：{a} -> {c}')
    move(n - 1, b, a, c)

n = int(input('输入n：'))
move(n,'A','B','C')
# Out:
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子5：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子6：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子5：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子7：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子5：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子6：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子5：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子8：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子5：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子6：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子5：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子7：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子5：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子6：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子5：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子9：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子5：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子6：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子5：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子7：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子5：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子6：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子5：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子8：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子5：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子6：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子5：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子7：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子5：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子6：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子5：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子10：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子5：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子6：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子5：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子7：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子5：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子6：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子5：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子8：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子5：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子6：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子5：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子7：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子5：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子6：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子5：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子9：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子5：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子6：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子5：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子7：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子5：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子6：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子5：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子8：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子5：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子6：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子5：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子7：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子5：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子4：C -> B
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子6：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子4：B -> A
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子3：C -> A
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子5：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# 移动盘子3：A -> B
# 移动盘子1：C -> A
# 移动盘子2：C -> B
# 移动盘子1：A -> B
# 移动盘子4：A -> C
# 移动盘子1：B -> C
# 移动盘子2：B -> A
# 移动盘子1：C -> A
# 移动盘子3：B -> C
# 移动盘子1：A -> B
# 移动盘子2：A -> C
# 移动盘子1：B -> C
# None
