# %%
import csv

with open(r'E:\Class\Coda\PythonBase\Day0528\a.csv','r',encoding='utf-8') as file:
    fileCsv = csv.reader(file)
    next(fileCsv)
    for i in fileCsv :
        # print(i)
        print(i[1])
# Out:
# 11112341234:12212341234:13312341234
# 21112341234:22212341234
# 31112341234

# %%
import csv
with open(r'E:\Class\Coda\PythonBase\Day0528\a.csv','a',encoding='utf-8', newline='') as file:
    fileCsv = csv.writer(file)
    fileCsv.writerow([1006,'张二',22])
    fileCsv.writerows([[1003,'王五',20],[1004,'赵六',21]])
